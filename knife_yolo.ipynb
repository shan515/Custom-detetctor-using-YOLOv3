# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13733, done.
# remote: Total 13733 (delta 0), reused 0 (delta 0), pack-reused 13733
# Receiving objects: 100% (13733/13733), 12.31 MiB | 10.17 MiB/s, done.
# Resolving deltas: 100% (9373/9373), done.

# %%
# !unzip "/content/knife.zip" -d "/content/darknet/"
# Out:
# Archive:  /content/knife.zip
#    creating: /content/darknet/knife/
#   inflating: /content/darknet/knife/knife_114.txt
#   inflating: /content/darknet/knife/knife_96.txt
#   inflating: /content/darknet/knife/knife_281.jpg
#   inflating: /content/darknet/knife/knife_223.jpg
#   inflating: /content/darknet/knife/knife_153.jpg
#   inflating: /content/darknet/knife/knife_6.jpg
#   inflating: /content/darknet/knife/knife_21.txt
#   inflating: /content/darknet/knife/knife_195.jpg
#   inflating: /content/darknet/knife/knife_112.txt
#   inflating: /content/darknet/knife/knife_217.txt
#   inflating: /content/darknet/knife/knife_141.jpg
#   inflating: /content/darknet/knife/knife_320.txt
#   inflating: /content/darknet/knife/knife_249.jpg
#   inflating: /content/darknet/knife/knife_163.txt
#   inflating: /content/darknet/knife/knife_235.txt
#   inflating: /content/darknet/knife/knife_68.jpg
#   inflating: /content/darknet/knife/knife_305.jpg
# ...

# %%
# !apt-get update
# !apt-get upgrade
# Out:
# Hit:1 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,622 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:9 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,840 kB]
# Ign:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# ...

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libavcodec-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.

# %%
# %cd /content/darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# %cd /content/darknet
# !make
# Out:
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 6 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (4,477 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./knife/train.txt
# !dos2unix ./knife/val.txt
# !dos2unix ./knife/yolo.data
# !dos2unix ./knife/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: converting file ./knife/train.txt to Unix format...
# dos2unix: converting file ./knife/val.txt to Unix format...
# dos2unix: converting file ./knife/yolo.data to Unix format...
# dos2unix: converting file ./knife/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3_custom_train.cfg to Unix format...

# %%
ls
# Out:
# 3rdparty/   CMakeLists.txt          image_yolov3.sh*        obj/
# backup/     darknet*                include/                README.md
# build/      DarknetConfig.cmake.in  json_mjpeg_streams.sh*  results/
# build.ps1*  darknet.py              knife/                  scripts/
# build.sh*   darknet_video.py        LICENSE                 src/
# cfg/        data/                   Makefile                video_v2.sh*
# cmake/      image_yolov2.sh*        net_cam_v3.sh*          video_yolov3.sh*

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-06-22 20:02:25--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   582KB/s    in 7m 31s
#
# 2020-06-22 20:09:58 (537 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/backup /content/darknet

# %%
# %cd /content/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# chmod +x *.sh

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg

# %%
# %cd /content/darknet 
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# /content/darknet
# --2020-06-22 20:39:46--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M   812KB/s    in 4m 48s
#
# 2020-06-22 20:44:36 (552 KB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# %cd /content/darknet
# !./darknet detector train knife/yolo.data cfg/yolov3_custom_train.cfg yolov3.weights -dont_show -map
# Out:
# /content/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# %cd /content/darknet
./darknet detector test knife/yolo.data knife/yolo
